# %%
#c4.5 1

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# Excel dosyasından verileri oku
df = pd.read_excel("/content/stemmervepunctuation (1).xlsx")
sentences = df["description"].values  # Cümleler
labels = df["Toplu"].values  # Sınıf etiketleri

# Özellik çıkarma: cümleleri kelime sayısına göre özellik olarak temsil et
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(df['description'].values.astype(str))

# Özellikleri standartlaştır
scaler = StandardScaler(with_mean=False, with_std=False)
X_scaled = scaler.fit_transform(X)

# Veri kümesini eğitim ve test kümelerine ayır
X_train, X_test, y_train, y_test = train_test_split(X_scaled, labels, test_size=0.3, random_state=42)

# C4.5 karar ağacı modelini oluştur
tree_clf = DecisionTreeClassifier(criterion='entropy')

# Modeli eğit
tree_clf.fit(X_train, y_train)

# Test kümesini kullanarak modeli değerlendir
accuracy = tree_clf.score(X_test, y_test)
print("Modelin doğruluk oranı: {:.2f}".format(accuracy))
# Out:
# Modelin doğruluk oranı: 0.59

# %%
#KULLANMA
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plot_tree(tree_clf, filled=True);
plt.show()

# %%
from sklearn.tree import export_text

# Karar ağacını metin tablosu olarak görüntüle
r = export_text(tree_clf, feature_names=list(vectorizer.vocabulary_.keys()))
print(r)
# Out:
# |--- çalışıyorum <= 0.50
# |   |--- oluk <= 0.50
# |   |   |--- ınstagramım <= 0.50
# |   |   |   |--- xanim <= 0.50
# |   |   |   |   |--- kaldigini <= 0.50
# |   |   |   |   |   |--- 63yaşındayım <= 0.50
# |   |   |   |   |   |   |--- kes <= 0.50
# |   |   |   |   |   |   |   |--- cayır <= 0.50
# |   |   |   |   |   |   |   |   |--- dkfjsjfj <= 0.50
# |   |   |   |   |   |   |   |   |   |--- yapmiyom <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- üts <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 249
# |   |   |   |   |   |   |   |   |   |   |--- üts >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- yapmiyom >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- yakismis <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- yakismis >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- dkfjsjfj >  0.50
# |   |   |   |   |   |   |   |   |   |--- ilgili <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- eksfoliasyon <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- eksfoliasyon >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- ilgili >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- cayır >  0.50
# |   |   |   |   |   |   |   |   |--- pirinç <= 0.50
# |   |   |   |   |   |   |   |   |   |--- citler <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- citler >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- pirinç >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- kes >  0.50
# |   |   |   |   |   |   |   |--- revolution <= 0.50
# |   |   |   |   |   |   |   |   |--- withdilara <= 0.50
# |   |   |   |   |   |   |   |   |   |--- videosunuu <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- 1000tllik <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- 1000tllik >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- videosunuu >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- withdilara >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- revolution >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- 63yaşındayım >  0.50
# |   |   |   |   |   |   |--- aydınlat <= 1.50
# |   |   |   |   |   |   |   |--- yazmis <= 0.50
# |   |   |   |   |   |   |   |   |--- deauty <= 0.50
# |   |   |   |   |   |   |   |   |   |--- cimbu <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- cimbu >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- deauty >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- yazmis >  0.50
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- aydınlat >  1.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- kaldigini >  0.50
# |   |   |   |   |   |--- buğday <= 0.50
# |   |   |   |   |   |   |--- purest <= 0.50
# |   |   |   |   |   |   |   |--- bat <= 0.50
# |   |   |   |   |   |   |   |   |--- ayrıca <= 0.50
# |   |   |   |   |   |   |   |   |   |--- agresif <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- alışkanlıkları <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |   |--- alışkanlıkları >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- agresif >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- 36 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- 36 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- ayrıca >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- bat >  0.50
# |   |   |   |   |   |   |   |   |--- plastik <= 1.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- plastik >  1.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- purest >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- buğday >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- xanim >  0.50
# |   |   |   |   |--- slikon <= 0.50
# |   |   |   |   |   |--- kedisi <= 0.50
# |   |   |   |   |   |   |--- büyüklerinin <= 0.50
# |   |   |   |   |   |   |   |--- tebessüm <= 0.50
# |   |   |   |   |   |   |   |   |--- erkek <= 0.50
# |   |   |   |   |   |   |   |   |   |--- yatır <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- kibir <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 31
# |   |   |   |   |   |   |   |   |   |   |--- kibir >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- yatır >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- eşya <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- eşya >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- erkek >  0.50
# |   |   |   |   |   |   |   |   |   |--- yakismis <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- xanim <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- xanim >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- yakismis >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- tebessüm >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- büyüklerinin >  0.50
# |   |   |   |   |   |   |   |--- citler <= 0.50
# |   |   |   |   |   |   |   |   |--- tepsi <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- tepsi >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- citler >  0.50
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- kedisi >  0.50
# |   |   |   |   |   |   |--- getirmişti <= 0.50
# |   |   |   |   |   |   |   |--- kiiii <= 0.50
# |   |   |   |   |   |   |   |   |--- evlâd <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- evlâd >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- kiiii >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- getirmişti >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- slikon >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |--- ınstagramım >  0.50
# |   |   |   |--- kısacası <= 0.50
# |   |   |   |   |--- erkek <= 0.50
# |   |   |   |   |   |--- önemi <= 0.50
# |   |   |   |   |   |   |--- glow <= 0.50
# |   |   |   |   |   |   |   |--- ağrı <= 0.50
# |   |   |   |   |   |   |   |   |--- değirmenci <= 0.50
# |   |   |   |   |   |   |   |   |   |--- rotinime <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- rotinime >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- değirmenci >  0.50
# |   |   |   |   |   |   |   |   |   |--- haber <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- cimbu <= 1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- cimbu >  1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- haber >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- ağrı >  0.50
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- glow >  0.50
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- önemi >  0.50
# |   |   |   |   |   |   |--- yıkıyomusun <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- yıkıyomusun >  0.50
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- erkek >  0.50
# |   |   |   |   |   |--- kızardıkca <= 0.50
# |   |   |   |   |   |   |--- cerave <= 0.50
# |   |   |   |   |   |   |   |--- olmadigim <= 0.50
# |   |   |   |   |   |   |   |   |--- silmek <= 1.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- silmek >  1.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- olmadigim >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- cerave >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- kızardıkca >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- kısacası >  0.50
# |   |   |   |   |--- türkmenistan <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- türkmenistan >  0.50
# |   |   |   |   |   |--- class: 2
# |   |--- oluk >  0.50
# |   |   |--- yakismis <= 0.50
# |   |   |   |--- kaldigini <= 0.50
# |   |   |   |   |--- cekmeni <= 0.50
# |   |   |   |   |   |--- 74 <= 0.50
# |   |   |   |   |   |   |--- kenarlarimda <= 0.50
# |   |   |   |   |   |   |   |--- cerave <= 0.50
# |   |   |   |   |   |   |   |   |--- birisiniz <= 0.50
# |   |   |   |   |   |   |   |   |   |--- eder <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- eeen <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- eeen >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- eder >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- iyrenclutfen <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- iyrenclutfen >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- birisiniz >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- cerave >  0.50
# |   |   |   |   |   |   |   |   |--- musluk <= 0.50
# |   |   |   |   |   |   |   |   |   |--- eder <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- vb <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- vb >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- eder >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- musluk >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- kenarlarimda >  0.50
# |   |   |   |   |   |   |   |--- talep <= 0.50
# |   |   |   |   |   |   |   |   |--- metin <= 0.50
# |   |   |   |   |   |   |   |   |   |--- oluk <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- oluk >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- metin >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- talep >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- 74 >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- cekmeni >  0.50
# |   |   |   |   |   |--- amele <= 0.50
# |   |   |   |   |   |   |--- kronik <= 0.50
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- kronik >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- amele >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- kaldigini >  0.50
# |   |   |   |   |--- dkfjsjfj <= 0.50
# |   |   |   |   |   |--- yuzü <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- yuzü >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- dkfjsjfj >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |--- yakismis >  0.50
# |   |   |   |--- xanim <= 0.50
# |   |   |   |   |--- art <= 0.50
# |   |   |   |   |   |--- reaksiyon <= 0.50
# |   |   |   |   |   |   |--- sevmis <= 0.50
# |   |   |   |   |   |   |   |--- yaşıyorumacaba <= 0.50
# |   |   |   |   |   |   |   |   |--- alıcaktım <= 0.50
# |   |   |   |   |   |   |   |   |   |--- seval <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- nemlendirm <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- nemlendirm >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- seval >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- alıcaktım >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- yaşıyorumacaba >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- sevmis >  0.50
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- reaksiyon >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- art >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- xanim >  0.50
# |   |   |   |   |--- önemi <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- önemi >  0.50
# |   |   |   |   |   |--- tesekur <= 0.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- tesekur >  0.50
# |   |   |   |   |   |   |--- class: 1
# |--- çalışıyorum >  0.50
# |   |--- ınstagramım <= 0.50
# |   |   |--- yaptircakmis <= 0.50
# |   |   |   |--- çal <= 0.50
# |   |   |   |   |--- kaldigini <= 0.50
# |   |   |   |   |   |--- yapm <= 0.50
# |   |   |   |   |   |   |--- kes <= 0.50
# |   |   |   |   |   |   |   |--- markada <= 0.50
# |   |   |   |   |   |   |   |   |--- oluk <= 0.50
# |   |   |   |   |   |   |   |   |   |--- tespit <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- tarak <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 26
# |   |   |   |   |   |   |   |   |   |   |--- tarak >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- tespit >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- yazikki <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- yazikki >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- oluk >  0.50
# |   |   |   |   |   |   |   |   |   |--- çalışıyorum <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- tepsi <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- tepsi >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- çalışıyorum >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- aynı <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- aynı >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- markada >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- kes >  0.50
# |   |   |   |   |   |   |   |--- aşşşırı <= 0.50
# |   |   |   |   |   |   |   |   |--- getirmişti <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- getirmişti >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- aşşşırı >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- yapm >  0.50
# |   |   |   |   |   |   |--- basım <= 0.50
# |   |   |   |   |   |   |   |--- art <= 0.50
# |   |   |   |   |   |   |   |   |--- eksfoliasyon <= 0.50
# |   |   |   |   |   |   |   |   |   |--- ayırt <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- türkmenistan <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- türkmenistan >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- ayırt >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- seyin <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- seyin >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- eksfoliasyon >  0.50
# |   |   |   |   |   |   |   |   |   |--- katrin <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- katrin >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- art >  0.50
# |   |   |   |   |   |   |   |   |--- gordum <= 0.50
# |   |   |   |   |   |   |   |   |   |--- eger <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- cult <= 1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- cult >  1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- eger >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- gordum >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- basım >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- kaldigini >  0.50
# |   |   |   |   |   |--- büyüklerinin <= 0.50
# |   |   |   |   |   |   |--- hiçbişey <= 0.50
# |   |   |   |   |   |   |   |--- yakismis <= 0.50
# |   |   |   |   |   |   |   |   |--- yaşıyorumacaba <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- yaşıyorumacaba >  0.50
# |   |   |   |   |   |   |   |   |   |--- muchhhhhhhh <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- muchhhhhhhh >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- yakismis >  0.50
# |   |   |   |   |   |   |   |   |--- purest <= 0.50
# |   |   |   |   |   |   |   |   |   |--- üşeniyordum <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- karşılaşma <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- karşılaşma >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- üşeniyordum >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- purest >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- hiçbişey >  0.50
# |   |   |   |   |   |   |   |--- çoğu <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- çoğu >  0.50
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- büyüklerinin >  0.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- çal >  0.50
# |   |   |   |   |--- cerave <= 0.50
# |   |   |   |   |   |--- pul <= 0.50
# |   |   |   |   |   |   |--- jumiso <= 0.50
# |   |   |   |   |   |   |   |--- slikon <= 0.50
# |   |   |   |   |   |   |   |   |--- lımonene <= 0.50
# |   |   |   |   |   |   |   |   |   |--- muzdarip <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- muzdarip >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- lımonene >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- slikon >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- jumiso >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- pul >  0.50
# |   |   |   |   |   |   |--- power <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- power >  0.50
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- cerave >  0.50
# |   |   |   |   |   |--- dupduru <= 0.50
# |   |   |   |   |   |   |--- kısacası <= 0.50
# |   |   |   |   |   |   |   |--- tesekur <= 0.50
# |   |   |   |   |   |   |   |   |--- çal <= 1.50
# |   |   |   |   |   |   |   |   |   |--- methylpropıonal <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- aslı <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- aslı >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- methylpropıonal >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- çal >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- tesekur >  0.50
# |   |   |   |   |   |   |   |   |--- şiş <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- şiş >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- kısacası >  0.50
# |   |   |   |   |   |   |   |--- cizrede <= 1.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- cizrede >  1.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- dupduru >  0.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |--- yaptircakmis >  0.50
# |   |   |   |--- amele <= 0.50
# |   |   |   |   |--- kullanacagimi <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- kullanacagimi >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- amele >  0.50
# |   |   |   |   |--- yakismis <= 0.50
# |   |   |   |   |   |--- peelingle <= 1.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- peelingle >  1.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- yakismis >  0.50
# |   |   |   |   |   |--- class: 1
# |   |--- ınstagramım >  0.50
# |   |   |--- kullanimda <= 1.50
# |   |   |   |--- uyar <= 0.50
# |   |   |   |   |--- katkı <= 0.50
# |   |   |   |   |   |--- bahar <= 0.50
# |   |   |   |   |   |   |--- denedigim <= 0.50
# |   |   |   |   |   |   |   |--- markasina <= 0.50
# |   |   |   |   |   |   |   |   |--- kurtulursunuz <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- kurtulursunuz >  0.50
# |   |   |   |   |   |   |   |   |   |--- almıştım <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- mervr <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- mervr >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- almıştım >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- markasina >  0.50
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- denedigim >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- bahar >  0.50
# |   |   |   |   |   |   |--- fırçala <= 0.50
# |   |   |   |   |   |   |   |--- oolllleeyyyyy <= 1.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- oolllleeyyyyy >  1.00
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- fırçala >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- katkı >  0.50
# |   |   |   |   |   |--- class: 2
# |   |   |   |--- uyar >  0.50
# |   |   |   |   |--- class: 0
# |   |   |--- kullanimda >  1.50
# |   |   |   |--- kedisi <= 0.50
# |   |   |   |   |--- class: 2
# |   |   |   |--- kedisi >  0.50
# |   |   |   |   |--- class: 0

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_score, recall_score, f1_score

# Karar ağacı modelini tanımlayın
model = DecisionTreeClassifier()

# Modeli eğitin
model.fit(X_train, y_train)

# Modeli kullanarak tahminler yapın
y_pred = model.predict(X_test)

# Precision, recall ve F-measure hesaplayın
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')
f_measure = f1_score(y_test, y_pred, average='macro')

print("Precision: {:.2f}".format(precision))
print("Recall: {:.2f}".format(recall))
print("F-measure: {:.2f}".format(f_measure))
# Out:
# Precision: 0.44
# Recall: 0.43
# F-measure: 0.43
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# df, vectorizer, scaler gibi değişkenlerin ve X_train, X_test, y_train, y_test'in tanımlandığı bir yer olduğunu varsayalım

# Binarize the labels
y_test_bin = label_binarize(y_test, classes=[0, 1, 2])

# Train the Naive Bayes classifier
nb_clf = MultinomialNB()
nb_clf.fit(X_train, y_train)

# Calculate the class probabilities
y_pred_prob = nb_clf.predict_proba(X_test)

# Calculate the false positive rate, true positive rate, and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
num_classes = 3  # Sınıf sayısı
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot the ROC curves for each class
plt.figure()
colors = ['blue', 'red', 'green']
for i, color in zip(range(num_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2, label='Class {} (AUC = {:.2f})'.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - OvA')
plt.legend(loc="lower right")
plt.show()

# %%
import numpy as np
from sklearn.metrics import roc_auc_score

# Determine the number of classes
num_classes = len(np.unique(y_test))

# Predict probabilities for each class
y_pred_prob = nb_clf.predict_proba(X_test)

# Calculate the ROC AUC score for each class
roc_area = []
for i in range(num_classes):
    y_true_binary = (y_test == i)  # Binary labels for the current class
    y_pred_prob_class = y_pred_prob[:, i]  # Predicted probabilities for the current class
    roc_area.append(round(roc_auc_score(y_true_binary, y_pred_prob_class), 2))

print("Approximate ROC Area for each class:", roc_area)
# Out:
# Approximate ROC Area for each class: [0.78, 0.85, 0.84]

# %%
from sklearn.metrics import mean_squared_error

# RMSE hesaplamak için mean_squared_error fonksiyonunu kullanın
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: {:.2f}".format(rmse))
# Out:
# RMSE: 0.88
